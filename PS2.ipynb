# %%
import pandas as pd

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
Sig_Eqs = pd.read_csv("Sig_Eqs.tsv",sep='\t')

# %%
Sig_Eqs
# Out:
#      Search Parameters       Id    Year    Mo    Dy    Hr    Mn   Sec     Tsu  \
# 0                   []      NaN     NaN   NaN   NaN   NaN   NaN   NaN     NaN
# 1                  NaN      1.0 -2150.0   NaN   NaN   NaN   NaN   NaN     NaN
# 2                  NaN      2.0 -2000.0   NaN   NaN   NaN   NaN   NaN     1.0
# 3                  NaN      3.0 -2000.0   NaN   NaN   NaN   NaN   NaN     NaN
# 4                  NaN   5877.0 -1610.0   NaN   NaN   NaN   NaN   NaN     3.0
# ...                ...      ...     ...   ...   ...   ...   ...   ...     ...
# 6393               NaN  10708.0  2023.0  10.0   7.0   6.0  41.0   3.0     NaN
# 6394               NaN  10711.0  2023.0  10.0   7.0   8.0  40.0  13.0     NaN
# 6395               NaN  10709.0  2023.0  10.0   8.0  20.0  25.0  23.0  5891.0
# 6396               NaN  10710.0  2023.0  10.0  11.0   0.0  41.0  56.0     NaN
# 6397               NaN  10712.0  2023.0  10.0  15.0   3.0  36.0   0.0     NaN
#
#          Vol  ... Total Missing Total Missing Description  Total Injuries  \
# 0        NaN  ...           NaN                       NaN             NaN
# 1        NaN  ...           NaN                       NaN             NaN
# 2        NaN  ...           NaN                       NaN             NaN
# 3        NaN  ...           NaN                       NaN             NaN
# 4     1351.0  ...           NaN                       NaN             NaN
# ...      ...  ...           ...                       ...             ...
# 6393     NaN  ...           NaN                       NaN          1950.0
# 6394     NaN  ...           NaN                       NaN             NaN
# 6395     NaN  ...           NaN                       NaN             NaN
# 6396     NaN  ...           NaN                       NaN           164.0
# 6397     NaN  ...           NaN                       NaN           153.0
#
#      Total Injuries Description  Total Damage ($Mil)  \
# 0                           NaN                  NaN
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# 3                           NaN                  NaN
# 4                           NaN                  NaN
# ...                         ...                  ...
# 6393                        4.0                  NaN
# 6394                        NaN                  NaN
# 6395                        NaN                  NaN
# 6396                        3.0                  NaN
# 6397                        3.0                  NaN
#
#       Total Damage Description  Total Houses Destroyed  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          1.0                     NaN
# 4                          3.0                     NaN
# ...                        ...                     ...
# 6393                       3.0                  2862.0
# 6394                       2.0                   200.0
# 6395                       NaN                     NaN
# 6396                       2.0                     NaN
# 6397                       2.0                     NaN
#
#       Total Houses Destroyed Description  Total Houses Damaged  \
# 0                                    NaN                   NaN
# 1                                    NaN                   NaN
# 2                                    NaN                   NaN
# 3                                    1.0                   NaN
# 4                                    NaN                   NaN
# ...                                  ...                   ...
# 6393                                 4.0                 250.0
# 6394                                 3.0                   NaN
# 6395                                 NaN                   NaN
# 6396                                 NaN                   NaN
# 6397                                 2.0                   NaN
#
#       Total Houses Damaged Description
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 6393                               3.0
# 6394                               2.0
# 6395                               NaN
# 6396                               NaN
# 6397                               NaN
#
# [6398 rows x 49 columns]

# %%
c=Sig_Eqs.groupby(['Country']).sum()['Deaths']
Sig_Eqs.groupby(['Country']).sum()['Deaths']
# Out:
# Country
# AFGHANISTAN                             15644.0
# ALBANIA                                  3132.0
# ALGERIA                                 39339.0
# ANTARCTICA                                  0.0
# ANTIGUA AND BARBUDA                         0.0
#                                          ...
# VENEZUELA                               44480.0
# VIETNAM                                     0.0
# WALLIS AND FUTUNA (FRENCH TERRITORY)        5.0
# YEMEN                                    4192.0
# ZAMBIA                                      0.0
# Name: Deaths, Length: 156, dtype: float64

# %%
Sig_Eqs.groupby(['Country']).sum()['Deaths'].sort_values(ascending=False).head(10)
# Out:
# Country
# CHINA         2075045.0
# TURKEY        1188881.0
# IRAN          1011449.0
# ITALY          498478.0
# SYRIA          439224.0
# HAITI          323478.0
# AZERBAIJAN     317219.0
# JAPAN          279085.0
# ARMENIA        191890.0
# PAKISTAN       145083.0
# Name: Deaths, dtype: float64

# %%
big=Sig_Eqs.loc[Sig_Eqs ['Mag'] > 6].groupby(['Year'])

# %%
big.size()
# Out:
# Year
# -2150.0     1
# -2000.0     1
# -1250.0     1
# -1050.0     1
# -479.0      1
#            ..
#  2019.0    27
#  2020.0    15
#  2021.0    23
#  2022.0    20
#  2023.0    22
# Length: 536, dtype: int64

# %%
big.size().plot()
# Out:
# <Axes: xlabel='Year'>

# %%
def CountEq_LargestEq(country):
    a=Sig_Eqs.loc[Sig_Eqs['Country']==country].size()
    b=Sig_Eqs.loc[Sig_Eqs['Country']==country].sort_values("Mag", ascending=False).head(1).Year
    return a,b

# %%
wind_speed = pd.read_csv("2281305.csv")
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_10596\3607340690.py:1: DtypeWarning: Columns (4,8,9,12,15,21,22,24,26,31,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   wind_speed = pd.read_csv("2281305.csv")

# %%
wind_speed['DATE'] = wind_speed['DATE'].astype('str')

# %%
wind_speed['DATE'] = pd.to_datetime(wind_speed['DATE'])

# %%
wind_speed['YEAR'] = wind_speed['DATE'].dt.year

# %%
wind_speed['MONTH'] = wind_speed['DATE'].dt.month

# %%
wind_speed['DAY'] = wind_speed['DATE'].dt.day

# %%
wind_speed
# Out:
#             STATION                DATE  SOURCE REPORT_TYPE CALL_SIGN  \
# 0       59493099999 2010-01-02 00:00:00       4       SY-MT     ZGSZ
# 1       59493099999 2010-01-02 01:00:00       4       FM-15     ZGSZ
# 2       59493099999 2010-01-02 02:00:00       4       FM-15     ZGSZ
# 3       59493099999 2010-01-02 03:00:00       4       SY-MT     ZGSZ
# 4       59493099999 2010-01-02 04:00:00       4       FM-15     ZGSZ
# ...             ...                 ...     ...         ...       ...
# 111979  59493099999 2020-09-11 17:00:00       4       FM-15     99999
# 111980  59493099999 2020-09-11 18:00:00       4       FM-15     99999
# 111981  59493099999 2020-09-11 19:00:00       4       FM-15     99999
# 111982  59493099999 2020-09-11 20:00:00       4       FM-15     99999
# 111983  59493099999 2020-09-11 21:00:00       4       FM-15     99999
#
#        QUALITY_CONTROL          AA1          AA2  AA3  AJ1  ...  \
# 0                 V020  06,0000,2,1  24,0000,2,1  NaN  NaN  ...
# 1                 V020          NaN          NaN  NaN  NaN  ...
# 2                 V020          NaN          NaN  NaN  NaN  ...
# 3                 V020          NaN          NaN  NaN  NaN  ...
# 4                 V020          NaN          NaN  NaN  NaN  ...
# ...                ...          ...          ...  ...  ...  ...
# 111979            V020          NaN          NaN  NaN  NaN  ...
# 111980            V020          NaN          NaN  NaN  NaN  ...
# 111981            V020          NaN          NaN  NaN  NaN  ...
# 111982            V020          NaN          NaN  NaN  NaN  ...
# 111983            V020          NaN          NaN  NaN  NaN  ...
#
#                                                       REM REPORT_TYPE.1  \
# 0       SYN088AAXX  02001 59493 11740 80402 10161 2013...         SY-MT
# 1       MET068METAR ZGSZ 020100Z VRB01MPS 2600 BR FEW0...         FM-15
# 2       MET068METAR ZGSZ 020200Z 00000MPS 2600 BR FEW0...         FM-15
# 3       SYN066AAXX  02031 59493 41750 81401 10192 2014...         SY-MT
# 4       MET068METAR ZGSZ 020400Z 30004MPS 2100 BR FEW0...         FM-15
# ...                                                   ...           ...
# 111979  MET058METAR ZGSZ 111700Z 17003MPS 9999 BKN020 ...         FM-15
# 111980  MET058METAR ZGSZ 111800Z 18004MPS 9999 BKN020 ...         FM-15
# 111981  MET088METAR ZGSZ 111900Z 22003MPS 200V260 9999...         FM-15
# 111982  MET067METAR ZGSZ 112000Z 26003MPS 9999 SCT020 ...         FM-15
# 111983  MET088METAR ZGSZ 112100Z 31002MPS 280V340 9999...         FM-15
#
#             SLP SOURCE.1      TMP           VIS             WND  YEAR MONTH  \
# 0       10161,1        4  +0161,1  004000,1,N,1  040,1,N,0020,1  2010     1
# 1       99999,9        4  +0170,1  002600,1,N,1  999,9,V,0010,1  2010     1
# 2       99999,9        4  +0180,1  002600,1,N,1  999,9,C,0000,1  2010     1
# 3       10169,1        4  +0192,1  005000,1,N,1  140,1,N,0010,1  2010     1
# 4       99999,9        4  +0180,1  002100,1,N,1  300,1,N,0040,1  2010     1
# ...         ...      ...      ...           ...             ...   ...   ...
# 111979  99999,9        4  +0290,1  009999,1,9,9  170,1,N,0030,1  2020     9
# 111980  99999,9        4  +0290,1  009999,1,9,9  180,1,N,0040,1  2020     9
# 111981  99999,9        4  +0290,1  009999,1,9,9  220,1,V,0030,1  2020     9
# 111982  99999,9        4  +0290,1  009999,1,9,9  260,1,N,0030,1  2020     9
# 111983  99999,9        4  +0290,1  009999,1,9,9  310,1,V,0020,1  2020     9
#
#        DAY
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
# ...     ..
# 111979  11
# 111980  11
# 111981  11
# 111982  11
# 111983  11
#
# [111984 rows x 46 columns]

# %%
wind_speed[['a','b','c','d','e']] = wind_speed.WND.str.split(',', expand = True)
wind_speed.drop(axis = 1, columns = 'WND', inplace = True)

# %%
wind_speed
# Out:
#             STATION                DATE  SOURCE REPORT_TYPE CALL_SIGN  \
# 0       59493099999 2010-01-02 00:00:00       4       SY-MT     ZGSZ
# 1       59493099999 2010-01-02 01:00:00       4       FM-15     ZGSZ
# 2       59493099999 2010-01-02 02:00:00       4       FM-15     ZGSZ
# 3       59493099999 2010-01-02 03:00:00       4       SY-MT     ZGSZ
# 4       59493099999 2010-01-02 04:00:00       4       FM-15     ZGSZ
# ...             ...                 ...     ...         ...       ...
# 111979  59493099999 2020-09-11 17:00:00       4       FM-15     99999
# 111980  59493099999 2020-09-11 18:00:00       4       FM-15     99999
# 111981  59493099999 2020-09-11 19:00:00       4       FM-15     99999
# 111982  59493099999 2020-09-11 20:00:00       4       FM-15     99999
# 111983  59493099999 2020-09-11 21:00:00       4       FM-15     99999
#
#        QUALITY_CONTROL          AA1          AA2  AA3  AJ1  ...      TMP  \
# 0                 V020  06,0000,2,1  24,0000,2,1  NaN  NaN  ...  +0161,1
# 1                 V020          NaN          NaN  NaN  NaN  ...  +0170,1
# 2                 V020          NaN          NaN  NaN  NaN  ...  +0180,1
# 3                 V020          NaN          NaN  NaN  NaN  ...  +0192,1
# 4                 V020          NaN          NaN  NaN  NaN  ...  +0180,1
# ...                ...          ...          ...  ...  ...  ...      ...
# 111979            V020          NaN          NaN  NaN  NaN  ...  +0290,1
# 111980            V020          NaN          NaN  NaN  NaN  ...  +0290,1
# 111981            V020          NaN          NaN  NaN  NaN  ...  +0290,1
# 111982            V020          NaN          NaN  NaN  NaN  ...  +0290,1
# 111983            V020          NaN          NaN  NaN  NaN  ...  +0290,1
#
#                  VIS  YEAR MONTH DAY    a  b  c     d  e
# 0       004000,1,N,1  2010     1   2  040  1  N  0020  1
# 1       002600,1,N,1  2010     1   2  999  9  V  0010  1
# 2       002600,1,N,1  2010     1   2  999  9  C  0000  1
# 3       005000,1,N,1  2010     1   2  140  1  N  0010  1
# 4       002100,1,N,1  2010     1   2  300  1  N  0040  1
# ...              ...   ...   ...  ..  ... .. ..   ... ..
# 111979  009999,1,9,9  2020     9  11  170  1  N  0030  1
# 111980  009999,1,9,9  2020     9  11  180  1  N  0040  1
# 111981  009999,1,9,9  2020     9  11  220  1  V  0030  1
# 111982  009999,1,9,9  2020     9  11  260  1  N  0030  1
# 111983  009999,1,9,9  2020     9  11  310  1  V  0020  1
#
# [111984 rows x 50 columns]

# %%
wind_speed['d'] = wind_speed['d'].astype('float')

# %%
wind_speed.groupby(['MONTH']).mean()['d'].plot()

# %%
nj = pd.read_csv("data.csv")

# %%
nj
# Out:
#              Date  TAVG (Degrees Fahrenheit)  TMAX (Degrees Fahrenheit)  \
# 0        1951/1/1                        NaN                       53.0
# 1        1951/1/2                       42.0                       45.0
# 2        1951/1/3                       44.0                       52.0
# 3        1951/1/4                       44.0                       58.0
# 4        1951/1/5                       49.0                       62.0
# ...           ...                        ...                        ...
# 26596  2023/10/29                       65.0                        NaN
# 26597  2023/10/30                       65.0                        NaN
# 26598  2023/10/31                       67.0                        NaN
# 26599   2023/11/1                       69.0                        NaN
# 26600   2023/11/2                       69.0                        NaN
#
#        TMIN (Degrees Fahrenheit)  PRCP (Inches)  SNOW (Inches)  SNWD (Inches)
# 0                           38.0           0.00            NaN            NaN
# 1                           39.0           0.01            NaN            NaN
# 2                           40.0           0.00            NaN            NaN
# 3                           34.0           0.00            NaN            NaN
# 4                           40.0           0.00            NaN            NaN
# ...                          ...            ...            ...            ...
# 26596                        NaN           0.00            NaN            NaN
# 26597                        NaN           0.00            NaN            NaN
# 26598                        NaN           0.00            NaN            NaN
# 26599                        NaN           0.00            NaN            NaN
# 26600                        NaN           0.00            NaN            NaN
#
# [26601 rows x 7 columns]

# %%
nj.dropna(
    axis=1,
    how='all'
)
# Out:
#              Date  TAVG (Degrees Fahrenheit)  TMAX (Degrees Fahrenheit)  \
# 0        1951/1/1                        NaN                       53.0
# 1        1951/1/2                       42.0                       45.0
# 2        1951/1/3                       44.0                       52.0
# 3        1951/1/4                       44.0                       58.0
# 4        1951/1/5                       49.0                       62.0
# ...           ...                        ...                        ...
# 26596  2023/10/29                       65.0                        NaN
# 26597  2023/10/30                       65.0                        NaN
# 26598  2023/10/31                       67.0                        NaN
# 26599   2023/11/1                       69.0                        NaN
# 26600   2023/11/2                       69.0                        NaN
#
#        TMIN (Degrees Fahrenheit)  PRCP (Inches)  SNWD (Inches)
# 0                           38.0           0.00            NaN
# 1                           39.0           0.01            NaN
# 2                           40.0           0.00            NaN
# 3                           34.0           0.00            NaN
# 4                           40.0           0.00            NaN
# ...                          ...            ...            ...
# 26596                        NaN           0.00            NaN
# 26597                        NaN           0.00            NaN
# 26598                        NaN           0.00            NaN
# 26599                        NaN           0.00            NaN
# 26600                        NaN           0.00            NaN
#
# [26601 rows x 6 columns]

# %%
njc=nj.loc[nj['TAVG (Degrees Fahrenheit)'] !="NaN"].groupby(['Date'])

# %%
njc.plot()
# Out:
# C:\Users\dell\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:509: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)
